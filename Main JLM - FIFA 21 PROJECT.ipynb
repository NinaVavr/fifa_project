# %%
#Main Goal: create a model to predict of overall score from the rest of footballer.

# %%
#Know which variables are correlated with ova.

# %%
#Removing the variable are not correlated.

# %% [markdown]
# def clean_data(df):
#     df.columns=[e.lower().replace('','_') for e in df.coulmns)
#     df=df.dropna(columns=[unnamed:_0])
#     df['column_1']= df['cloumn_1'].fillna('M')
#     df=df.dropna()
#     df['column']=pd.to_datetime(df['clolumn']), errors='coerce')
#     df['month']= df['column'].dt.month
#     return df

# %%
#Fifa_data=clean_fifa(Fifa)

# %%
#round(data.isna().sum()/len(data),4)*100 #Shows the percentage of number of null values in a colulmn

# %%
import pandas as pd
import numpy as np

# %%
fifa = pd.read_csv('copy_fifa21_train.csv')

# %%
#fifa

# %%
fifa.describe()
# Out:
#                   ID          Age        Growth     Attacking      Crossing  \
# count   11701.000000  11701.00000  11701.000000  11701.000000  11701.000000
# mean   219436.649004     25.27049      5.534655    258.482181     51.593795
# std     37480.006004      4.95764      5.810903     72.267012     17.872747
# min        27.000000     16.00000     -1.000000     33.000000      6.000000
# 25%    204060.000000     21.00000      0.000000    232.000000     41.000000
# 50%    229040.000000     25.00000      4.000000    271.000000     56.000000
# 75%    244176.000000     29.00000     10.000000    306.000000     65.000000
# max    259090.000000     43.00000     26.000000    437.000000     94.000000
#
#           Finishing  Heading Accuracy  Short Passing       Volleys  \
# count  11701.000000      11701.000000   11701.000000  11660.000000
# mean      48.048116         53.494060      60.436800     45.067324
# std       19.399617         16.956195      13.971811     17.732902
# ...

# %%
fifa.shape
# Out:
# (11701, 101)

# %%
categorial_heads = fifa.select_dtypes(include=['object']).columns.tolist()
print(categorial_heads)
# Out:
# ['Name', 'Nationality', 'Club', 'BP', 'Position', 'Team & Contract', 'Height', 'Weight', 'foot', 'Joined', 'Loan Date End', 'Value', 'Wage', 'Release Clause', 'Contract', 'W/F', 'SM', 'A/W', 'D/W', 'IR', 'Hits', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'GK']

# %%
numerical_heads = fifa.select_dtypes(include=['number']).columns.tolist()
print(numerical_heads)
# Out:
# ['ID', 'Age', 'Growth', 'Attacking', 'Crossing', 'Finishing', 'Heading Accuracy', 'Short Passing', 'Volleys', 'Skill', 'Dribbling', 'Curve', 'FK Accuracy', 'Long Passing', 'Ball Control', 'Movement', 'Acceleration', 'Sprint Speed', 'Agility', 'Reactions', 'Balance', 'Power', 'Shot Power', 'Jumping', 'Stamina', 'Strength', 'Long Shots', 'Mentality', 'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure', 'Defending', 'Marking', 'Standing Tackle', 'Sliding Tackle', 'Goalkeeping', 'GK Diving', 'GK Handling', 'GK Kicking', 'GK Positioning', 'GK Reflexes', 'Total Stats', 'Base Stats', 'PAC', 'SHO', 'PAS', 'DRI', 'DEF', 'PHY', 'OVA']

# %%
pd.set_option('display.max_columns', None)

# %%
fifa.select_dtypes(np.number)
# Out:
#            ID  Age  Growth  Attacking  Crossing  Finishing  Heading Accuracy  \
# 0      184383   26       1        258        54         47                43
# 1      188044   30       0        365        66         79                76
# 2      184431   33       0        336        73         76                34
# 3      233796   22      13        242        44         42                58
# 4      234799   23       8        249        49         37                61
# ...       ...  ...     ...        ...       ...        ...               ...
# 11696  232504   25       5        224        62         24                51
# 11697  214680   27       4         84        12         14                13
# 11698  221489   22       8        286        64         66                51
# 11699  146717   26       7        254        64         66                51
# 11700  236507   22       9        289        43         64                65
#
# ...

# %%
fifa.dtypes
# Out:
# ID              int64
# Name           object
# Age             int64
# Nationality    object
# Club           object
#                 ...
# CB             object
# RCB            object
# RB             object
# GK             object
# OVA             int64
# Length: 101, dtype: object

# %%
print(fifa.dtypes)
# Out:
# ID              int64
# Name           object
# Age             int64
# Nationality    object
# Club           object
#                 ...
# CB             object
# RCB            object
# RB             object
# GK             object
# OVA             int64
# Length: 101, dtype: object

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(fifa.dtypes)
# Out:
# ID                    int64
# Name                 object
# Age                   int64
# Nationality          object
# Club                 object
# BP                   object
# Position             object
# Team & Contract      object
# Height               object
# Weight               object
# foot                 object
# Growth                int64
# Joined               object
# Loan Date End        object
# Value                object
# Wage                 object
# Release Clause       object
# Contract             object
# Attacking             int64
# Crossing              int64
# Finishing             int64
# Heading Accuracy      int64
# Short Passing         int64
# Volleys             float64
# Skill                 int64
# Dribbling             int64
# Curve               float64
# FK Accuracy           int64
# Long Passing          int64
# Ball Control          int64
# Movement              int64
# Acceleration          int64
# Sprint Speed          int64
# ...

# %%
fifa1 = fifa.drop(columns=['ID', 'Name', 'Nationality', 'Club', 'Team & Contract', "Joined", "Loan Date End", "Release Clause", "Contract", "A/W", "D/W"], axis=1)

# %%
cols1 = []
for column in fifa1.columns:
    cols1.append(column.lower())
cols1
fifa1.columns = cols1

fifa1.head()

fifa1
# Out:
#        age   bp   position height  weight   foot  growth  value  wage  \
# 0       26   CM     CM CDM   5'9"  161lbs  Right       1  €525K   €4K
# 1       30   ST   ST LW LM   6'0"  159lbs  Right       0  €8.5M  €23K
# 2       33  CAM     CAM CF   5'4"  134lbs  Right       0    €9M  €49K
# 3       22  CDM     CDM CM  5'10"  152lbs  Right      13  €275K   €4K
# 4       23  CDM     CDM CM  5'11"  150lbs  Right       8  €725K   €2K
# ...    ...  ...        ...    ...     ...    ...     ...    ...   ...
# 11696   25   LB         LB   6'1"  168lbs   Left       5  €625K   €3K
# 11697   27   GK         GK   6'1"  174lbs  Right       4  €1.6M   €4K
# 11698   22   RM  LM CAM RM   5'6"  143lbs  Right       8  €1.1M   €2K
# 11699   26   CM        NaN   6'2"  179lbs  Right       7     €0    €0
# 11700   22  CAM  ST CAM LM   5'7"  143lbs   Left       9  €700K   €2K
#
#        attacking  crossing  finishing  heading accuracy  short passing  \
# ...

# %%
def get_first_two(string):
    return int(string[:2])

# %%
cols = ['lcm', 'cm', 'cdm']
for col in cols:
    fifa1[col] = fifa1[col].apply(get_first_two)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 3
#       1 cols = ['lcm', 'cm', 'cdm']
#       2 for col in cols:
# ----> 3     fifa1[col] = fifa1[col].apply(get_first_two)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\series.py:4430, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4320 def apply(
#    4321     self,
#    4322     func: AggFuncType,
#    (...)
#    4325     **kwargs,
#    4326 ) -> DataFrame | Series:
#    4327     """
#    4328     Invoke function on values of Series.
#    4329
#    (...)
#    4428     dtype: float64
#    4429     """
# -> 4430     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\apply.py:1082, in SeriesApply.apply(self)
#    1078 if isinstance(self.f, str):
# ...

# %%
# Out:
#        age   bp   position height  weight   foot  growth  value  wage  \
# 0       26   CM     CM CDM   5'9"  161lbs  Right       1  €525K   €4K
# 1       30   ST   ST LW LM   6'0"  159lbs  Right       0  €8.5M  €23K
# 2       33  CAM     CAM CF   5'4"  134lbs  Right       0    €9M  €49K
# 3       22  CDM     CDM CM  5'10"  152lbs  Right      13  €275K   €4K
# 4       23  CDM     CDM CM  5'11"  150lbs  Right       8  €725K   €2K
# ...    ...  ...        ...    ...     ...    ...     ...    ...   ...
# 11696   25   LB         LB   6'1"  168lbs   Left       5  €625K   €3K
# 11697   27   GK         GK   6'1"  174lbs  Right       4  €1.6M   €4K
# 11698   22   RM  LM CAM RM   5'6"  143lbs  Right       8  €1.1M   €2K
# 11699   26   CM        NaN   6'2"  179lbs  Right       7     €0    €0
# 11700   22  CAM  ST CAM LM   5'7"  143lbs   Left       9  €700K   €2K
#
#        attacking  crossing  finishing  heading accuracy  short passing  \
# ...

# %%
rw = 'rw'
unique_counts = fifa1[rw].value_counts()
print(unique_counts)

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(fifa1['rw'].unique())

# %%
fifa1['height'] = (fifa1['height'].str.extract(r'(\d+)\'\s*(\d+)"').astype(float).mul([12*2.54, 2.54]).sum(axis=1))

# %%
fifa1

# %%
categorial_heads = fifa1.select_dtypes(include=['object']).columns.tolist()
print(categorial_heads)

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(fifa.dtypes)
# Out:
# ID                    int64
# Name                 object
# Age                   int64
# Nationality          object
# Club                 object
# BP                   object
# Position             object
# Team & Contract      object
# Height               object
# Weight               object
# foot                 object
# Growth                int64
# Joined               object
# Loan Date End        object
# Value                object
# Wage                 object
# Release Clause       object
# Contract             object
# Attacking             int64
# Crossing              int64
# Finishing             int64
# Heading Accuracy      int64
# Short Passing         int64
# Volleys             float64
# Skill                 int64
# Dribbling             int64
# Curve               float64
# FK Accuracy           int64
# Long Passing          int64
# Ball Control          int64
# Movement              int64
# Acceleration          int64
# Sprint Speed          int64
# ...

# %%
categorial_heads = fifa1.select_dtypes(include=['object']).columns.tolist()
print(categorial_heads)
# Out:
# ['bp', 'position', 'height', 'weight', 'foot', 'value', 'wage', 'w/f', 'sm', 'ir', 'hits', 'st', 'rs', 'lw', 'lf', 'cf', 'rf', 'rw', 'lam', 'cam', 'ram', 'lm', 'cm', 'rcm', 'rm', 'lwb', 'ldm', 'lb', 'lcb', 'cb', 'rcb', 'rb', 'gk']

# %%
fifa1.columns
# Out:
# Index(['age', 'bp', 'position', 'height', 'weight', 'foot', 'growth', 'value',
#        'wage', 'attacking', 'crossing', 'finishing', 'heading accuracy',
#        'short passing', 'volleys', 'skill', 'dribbling', 'curve',
#        'fk accuracy', 'long passing', 'ball control', 'movement',
#        'acceleration', 'sprint speed', 'agility', 'reactions', 'balance',
#        'power', 'shot power', 'jumping', 'stamina', 'strength', 'long shots',
#        'mentality', 'aggression', 'interceptions', 'positioning', 'vision',
#        'penalties', 'composure', 'defending', 'marking', 'standing tackle',
#        'sliding tackle', 'goalkeeping', 'gk diving', 'gk handling',
#        'gk kicking', 'gk positioning', 'gk reflexes', 'total stats',
#        'base stats', 'w/f', 'sm', 'ir', 'pac', 'sho', 'pas', 'dri', 'def',
#        'phy', 'hits', 'ls', 'st', 'rs', 'lw', 'lf', 'cf', 'rf', 'rw', 'lam',
#        'cam', 'ram', 'lm', 'lcm', 'cm', 'rcm', 'rm', 'lwb', 'ldm', 'cdm',
# ...

# %%
fifa1 = fifa1.ipynb('FIFA21.ipynb')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 fifa1 = fifa1.ipynb('FIFA21.ipynb')
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\generic.py:5583, in NDFrame.__getattr__(self, name)
#    5576 if (
#    5577     name not in self._internal_names_set
#    5578     and name not in self._metadata
#    5579     and name not in self._accessors
#    5580     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5581 ):
#    5582     return self[name]
# -> 5583 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'ipynb'

# %%
columns_drop = nulls_df[nulls_df['percent_nulls']>1]['header_name']  
print(columns_drop.values)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 columns_drop = nulls_df[nulls_df['percent_nulls']>1]['header_name']
#       2 print(columns_drop.values)
#
# NameError: name 'nulls_df' is not defined

# %%
mean_median_home_value = donors['median_home_val'].mean()
mean_median_home_value
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 mean_median_home_value = donors['median_home_val'].mean()
#       2 mean_median_home_value
#
# NameError: name 'donors' is not defined

# %%
donors['median_home_val'] = donors['median_home_val'].fillna(mean_median_home_value)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 donors['median_home_val'] = donors['median_home_val'].fillna(mean_median_home_value)
#
# NameError: name 'donors' is not defined

# %%
fifa1['position'].value_counts(dropna=False)
# Out:
# CB           1352
# ST           1267
# GK           1040
# CDM CM        515
# CM            449
#              ...
# RB CM CAM       1
# CF RM RW        1
# LB LWB RB       1
# LB CM LW        1
# RW LM CAM       1
# Name: position, Length: 544, dtype: int64

# %%
fifa1['position']=fifa1['position'].fillna('CB')

# %%
cols_to_check = ['rw', 'lw', 'cf', 'rf', 'lf', 'rs', 'ls', 'lam', 'cam', 'ram', 'lm', 'lcm', 'cm', 'rcm', 'rm', 'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb']

for col in cols_to_check:
    q1 = fifa1[col].quantile(0.25)
    q3 = fifa1[col].quantile(0.75)
    iqr = q3 - q1
    upper_bound = q3 + 1.5*iqr
    lower_bound = q1 - 1.5*iqr
    outliers = fifa1[(fifa1[col] < lower_bound) | (fifa1[col] > upper_bound)][col]
    print(f"Number of outliers in {col}: {len(outliers)}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 4
#       1 cols_to_check = ['rw', 'lw', 'cf', 'rf', 'lf', 'rs', 'ls', 'lam', 'cam', 'ram', 'lm', 'lcm', 'cm', 'rcm', 'rm', 'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb']
#       3 for col in cols_to_check:
# ----> 4     q1 = fifa1[col].quantile(0.25)
#       5     q3 = fifa1[col].quantile(0.75)
#       6     iqr = q3 - q1
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\series.py:2504, in Series.quantile(self, q, interpolation)
#    2500 # We dispatch to DataFrame so that core.internals only has to worry
#    2501 #  about 2D cases.
#    2502 df = self.to_frame()
# -> 2504 result = df.quantile(q=q, interpolation=interpolation, numeric_only=False)
#    2505 if result.ndim == 2:
#    2506     result = result.iloc[:, 0]
#
# ...

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(fifa1.dtypes)
# Out:
# age                   int64
# bp                   object
# position             object
# height               object
# weight               object
# foot                 object
# growth                int64
# value                object
# wage                 object
# attacking             int64
# crossing              int64
# finishing             int64
# heading accuracy      int64
# short passing         int64
# volleys             float64
# skill                 int64
# dribbling             int64
# curve               float64
# fk accuracy           int64
# long passing          int64
# ball control          int64
# movement              int64
# acceleration          int64
# sprint speed          int64
# agility             float64
# reactions             int64
# balance             float64
# power                 int64
# shot power            int64
# jumping             float64
# stamina               int64
# strength              int64
# long shots            int64
# ...
